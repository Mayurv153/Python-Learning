# %% [markdown]
# # 🚀 Advanced Arguments: *args and **kwargs
#
# When you don't know the exact number of arguments your function will receive, Python provides two special tools: `*args` and `**kwargs`.
#
# ---
#
# ### 1. 📦 Non-Keyword Arguments (`*args`)
# The `*args` syntax allows a function to accept any number of **positional arguments**. Inside the function, `args` is treated as a **tuple**.

# %%
# Function that sums up all numbers passed to it
def sum_all(*numbers):
    # 'numbers' is a tuple of all provided positional arguments
    total = 0
    for num in numbers:
        total += num
    return total

# Testing with different numbers of arguments
print(f"Sum 1: {sum_all(1, 2, 3)}")        # Output: 6
print(f"Sum 2: {sum_all(10, 20, 30, 40)}") # Output: 100

# %% [markdown]
# ### 2. 🏷️ Keyword Arguments (`**kwargs`)
# The `**kwargs` syntax allows a function to accept any number of **keyword (named) arguments**. Inside the function, `kwargs` is treated as a **dictionary**.

# %%
# Function that prints user details dynamically
def display_profile(**details):
    # 'details' is a dictionary of keyword arguments
    for key, value in details.items():
        print(f"{key.capitalize()}: {value}")

# Calling with arbitrary keyword arguments
display_profile(name="Mayur", role="Developer", city="Pune")

# %% [markdown]
# ### 3. 🧩 Combining All Argument Types
# When combining them, you must follow this specific order:
# 1. Positional arguments
# 2. Default arguments
# 3. `*args`
# 4. `**kwargs`

# %%
# Demonstrating a function that uses various argument types
def complex_function(a, b, *args, **kwargs):
    print(f"Required: a={a}, b={b}")
    print(f"Extra positional (*args): {args}")
    print(f"Extra keyword (**kwargs): {kwargs}")

# Calling the complex function
complex_function(1, 2, 3, 4, 5, x=100, y=200)

# %% [markdown]
# ---
#
# > ✨ **Pro Tip:** Remember that `args` and `kwargs` are conventions — the `*` and `**` are what actually do the magic!
#
# ---
